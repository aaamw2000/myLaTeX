# %% [markdown]
# ### Here we are importing the needed libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import shapiro, levene

# %%
df= pd.read_csv(r"/home/amr/Repos/myLaTeX/mvsReport/housing.csv")

# %% [markdown]
# ### Here we are exploring the data

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %% [markdown]
# ### We have 20640 records!

# %%
df.shape
# Out:
# (20640, 10)

# %% [markdown]
# ### Exploring the data types of each field

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# # Descriptive statistics

# %% [markdown]
# ### Mean vector, STD vector, quantiles, min & max

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %% [markdown]
# ### Checking to see if there are any null values

# %%
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %% [markdown]
# ### Filling the null values with the median

# %%
df = df.fillna(df['total_bedrooms'].median())

# %% [markdown]
# ### Checking for duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %% [markdown]
# ### Testing for normality

# %%
from scipy.stats import shapiro
from scipy import stats
numeric_cols = df.select_dtypes(include=np.number).columns

for col in numeric_cols:
    data = df[col]
    stat, p_value = stats.shapiro(data)
    print(f"\nColumn: {col}")
    print(f"Shapiro Statistic: {stat:.4f}, P-value: {p_value:.4e}")
    if p_value > 0.05:
        print("Normal")
    else:
        print("Not normal")
# Out:
# Column: longitude
# Shapiro Statistic: 0.8970, P-value: 4.1213e-78
# Not normal
#
# Column: latitude
# Shapiro Statistic: 0.8771, P-value: 4.4952e-82
# Not normal
#
# Column: housing_median_age
# Shapiro Statistic: 0.9782, P-value: 1.5602e-47
# Not normal
#
# Column: total_rooms
# Shapiro Statistic: 0.6952, P-value: 4.7783e-104
# Not normal
#
# Column: total_bedrooms
# Shapiro Statistic: nan, P-value: nan
# Not normal
#
# Column: population
# Shapiro Statistic: 0.7133, P-value: 1.7445e-102
# Not normal
#
# Column: households
# Shapiro Statistic: 0.7456, P-value: 1.8379e-99
# Not normal
#
# Column: median_income
# Shapiro Statistic: 0.8932, P-value: 6.5600e-79
# Not normal
#
# Column: median_house_value
# Shapiro Statistic: 0.9123, P-value: 1.3673e-74
# Not normal

# %% [markdown]
# ### Test of equal variances

# %%
group1 = df[df['ocean_proximity'] == 'INLAND']['median_house_value']
group2 = df[df['ocean_proximity'] == 'NEAR BAY']['median_house_value']

stat, p_value = levene(group1, group2)
print("\nLevene Test (Equal Variance):")
print(f"Statistic: {stat:.4f}, P-value: {p_value:.4e}")
if p_value > 0.05:
    print("✅ Variances are equal")
else:
    print("❌ Variances are NOT equal")
# Out:
# Levene Test (Equal Variance):
# Statistic: 1318.1708, P-value: 3.7005e-269
# ❌ Variances are NOT equal

# %% [markdown]
# ### Mean vector

# %%
df.mean(numeric_only=True)
# Out:
# longitude               -119.569704
# latitude                  35.631861
# housing_median_age        28.639486
# total_rooms             2635.763081
# total_bedrooms           536.838857
# population              1425.476744
# households               499.539680
# median_income              3.870671
# median_house_value    206855.816909
# dtype: float64

# %% [markdown]
# ### Covariance Matrix

# %%
df.cov(numeric_only=True)
# Out:
#                        longitude      latitude  housing_median_age  \
# longitude               4.014139     -3.957054           -2.728244
# latitude               -3.957054      4.562293            0.300346
# housing_median_age     -2.728244      0.300346          158.396260
# total_rooms           194.803750   -168.217847        -9919.120060
# total_bedrooms         58.078858    -59.556355        -1683.910513
# population            226.377839   -263.137814        -4222.270582
# households             42.368072    -58.010245        -1457.581290
# median_income          -0.057765     -0.323860           -2.846140
# median_house_value -10627.425205 -35532.559074       153398.801329
#
#                      total_rooms  total_bedrooms    population    households  \
# longitude           1.948037e+02    5.807886e+01  2.263778e+02  4.236807e+01
# latitude           -1.682178e+02   -5.955635e+01 -2.631378e+02 -5.801024e+01
# ...

# %% [markdown]
# ## Heat Map Graph

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="YlGnBu")  
plt.title("Correlation Matrix")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['total_bedrooms'])
plt.title('Boxplot of total_bedrooms')
plt.savefig('total_bedrooms.png')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='ocean_proximity', data=df)
plt.title('Count plot of ocean_proximity')
plt.savefig('ocean_proximity.png')
plt.show()
